# %% [markdown]
# #The second part - The GAN, which makes a face into a painting

# %% [markdown]
# # Credits
#
# For much of the code, we wanna give credit to the original github project: https://github.com/hardikbansal/CycleGAN
# For now it resembles it way too much, but we will try to improve it further.

# %% [markdown]
# # Settings

# %% [markdown]
# Mounting the drive, imports

# %%
from google.colab import drive
# %cd /content
drive.mount('/content/drive')
# Out:
# /content
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/deeplearning/resource/painting.zip -d /content/drive/MyDrive/deeplearning/resource/
# Out:
# Archive:  /content/drive/MyDrive/deeplearning/resource/painting.zip
#    creating: /content/drive/MyDrive/deeplearning/resource/painting/test/
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_st-george-struggling-with-the-dragon-1505.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_st-john-the-baptist-in-the-desert-1520.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_st-margaret-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_st-michael-1505.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_st-michael-overwhelming-the-demon-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_st-paul-preaching-at-athens-cartoon-for-the-sistine-chapel.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_st-peter-escapes-with-the-angel-from-the-liberation-of-saint-peter-in-the-stanza-d-eliodoro-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_st-sebastian-1502.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_studies-for-the-transfiguration.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-for-adam-1509.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-for-st-paul-preaching-in-athens-1515.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-for-the-disputa-1509.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-for-the-entombment-in-the-galleria-borghese-rome.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-for-the-head-1507.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-for-the-head-of-a-poet.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-for-the-holy-family-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-for-the-knight-s-dream.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_study-of-god-the-father-1515.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_terranuova-madonna.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-adoration-of-the-magi-1503.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-alba-madonna.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-alba-madonna-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-aldobrandini-madonna-or-the-garvagh-madonna-1510.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-annunciation-1503.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-baptism-of-constantine.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-battle-at-pons-milvius.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-battle-of-ostia-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-blessing-christ.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-blinding-of-elymas-cartoon-for-the-sistine-chapel.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-coronation-of-charlemagne-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-creation-of-the-animals-1519.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-crowning-of-the-virgin-1503.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-death-of-ananias-cartoon-for-the-sistine-chapel.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-deposition-1507.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-deposition-1507-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-disputation-of-the-holy-sacrament-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-esterhazy-madonna-1508.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-expulsion-of-heliodorus-from-the-temple-1512.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-fall-on-the-road-to-calvary-1517.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-fire-in-the-borgo-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-grand-duke-s-madonna-1505.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-guards-outside-the-prison-detail-from-the-liberation-of-st-peter-in-the-stanza-d-eliodoro-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-healing-of-the-lame-man-cartoon-for-the-sistine-chapel.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-holy-family-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-holy-family-of-the-oak-tree.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-holy-family-with-a-lamb-1507.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-holy-family-with-saints-elizabeth-and-john.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-judgment-of-solomon-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-judgment-of-solomon-1519.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-judicial-virtues-pope-gregory-ix-approving-the-vatical-decretals-justinian-handing-the.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-liberation-of-st-peter-in-the-stanza-d-eliodoro-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-liberation-of-st-peter-in-the-stanza-d-eliodoro-1514-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-madonna-and-child-with-st-john-the-baptist-and-st-nicholas-of-bari-1505.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-madonna-conestabile-1502.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-madonna-of-foligno-1512.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-madonna-of-loreto-1509.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-madonna-of-the-blue-diadem-or-the-madonna-of-the-veil.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-madonna-of-the-chair-1515.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-madonna-of-the-fish-the-madonna-with-the-archangel-gabriel-and-st-jerome.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-marriage-of-the-virgin-1504.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-marriage-of-the-virgin-1504-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-mass-at-bolsena-detail-1512.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-mass-of-bolsena-from-the-stanza-dell-eliodor-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-mass-of-bolsena-from-the-stanza-dell-eliodor-detail-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-miraculous-draught-of-fishes-cartoon-for-the-sistine-chapel.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_theological-virtues-1507.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_theology-from-the-stanza-della-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-parnassus-detail-of-homer-dante-and-virgil-in-the-stanze-della-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-parnassus-from-the-stanza-delle-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-parnassus-from-the-stanza-delle-segnatura-detail-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-parnassus-from-the-stanza-delle-segnatura-detail-1511-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-parnassus-from-the-stanza-delle-segnatura-detail-1511-2.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-parnassus-from-the-stanza-delle-segnatura-detail-1511-3.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-pregnant-woman-la-donna-gravida-1507.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-presentation-in-the-temple-1503.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-prophet-isaiah-1512.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-school-of-athens-detail-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-separation-of-land-and-water-1519.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-serpent-the-cross.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-sibyls-santa-maria-della-pace.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-sistine-madonna-1513.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-three-graces-1505.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-transfiguration-1520.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-transfiguration-detail-1520.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-transfiguration-detail-1520-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-triumph-of-galatea-detail-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-triumph-of-galatea-detail-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-veiled-woman-or-la-donna-velata.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-virgin-and-child-with-saint-john-the-baptist-1507.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-virgin-of-the-house-of-orleans-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-virgin-of-the-rose.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-virtues-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_the-visitation.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_tommaso-fedra-inghrami.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_vision-of-a-knight.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_vision-of-ezekiel-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/raphael_vision-of-the-cross.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_allegoria-macabra-1520.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_assumption-of-the-virgin-1517.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_assumption-of-the-virgin-detail-1517.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_dead-christ-with-angels-1526.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_death-of-cleopatra-1525.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_deposition-1521.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_deposition-from-the-cross-detail-1528.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_madonna-and-child-with-putti-1522.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_madonna-enthroned-and-ten-saints-1522.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_moses-defending-the-daughters-of-jethro-1523.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_moses-defending-the-daughters-of-jethro-detail-1524.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_piet-1540.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_playing-putto-musician-angel-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_risen-christ-1530.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_san-giovannino-1521.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_the-challenge-of-the-pierides-1520.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_the-holy-family-1520.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/rosso-fiorentino_the-holy-family-with-the-infant-saint-john-the-baptist-1521.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_adoration-of-the-child(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_adoration-of-the-magi(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_adoration-of-the-magi-1467(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_adoration-of-the-magi-1476-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_adoration-of-the-magi-1500(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_allegory-of-abundance-1485(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_angel(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_annunciation-1481(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_annunciation-1500(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_annunciation-cestello-detail-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_baptism-of-st-zenobius-and-his-appointment-as-bishop-1505(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_calumny-of-apelles(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_christ-carrying-the-cross(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_christ-crowned-with-thorns(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_christ-in-the-sepulchre(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_crucifixion(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_figures-on-the-road-to-calvary(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_fortitude(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_giuliano-de-medici-1478(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_illustration-to-the-divine-comedy-inferno-1480(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_inferno-canto-xviii-1480(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_inferno-canto-xxxi-1480(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_judith-leaving-the-tent-of-holofernes-1500(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_lamentation-over-the-dead-christ-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_last-communion-of-st-jerome(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-and-child(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-and-child-1470(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-and-child-1510(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-and-child-and-the-young-st-john-the-baptist-1495(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-and-child-with-an-angel(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-and-child-with-six-saints(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-and-child-with-st-john-the-baptist(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-and-child-with-two-angels(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-del-magnificat-1485(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-in-glory-with-seraphim-1470(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-of-the-book(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-of-the-magnificat-1481(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-of-the-rosegarden-1470(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-of-the-sea(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-with-child-and-singing-angels(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-with-child-and-three-angels(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_madonna-with-two-angels(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_pallas(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_pallas-and-centaur(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_paradise-canto-vi-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_paradise-canto-xxx-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_pity-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-man(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-man-1(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-man-with-the-medal-of-cosimo-1474(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-young-man(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-young-man-1483(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-young-man-1483-1(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-young-man-with-red-cap(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-young-man-with-red-cap-1477(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-young-woman(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-young-woman-1(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-a-young-woman-1485(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-dante(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_portrait-of-simonetta-vespucci(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_primavera-1478(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_purgatory-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_saint-jean-baptiste-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_salome-with-the-head-of-st-john-the-baptist(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_santa-maria-novella(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_scene-from-the-life-of-moses-1482(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_scene-from-the-life-of-moses-scenes-on-the-left-1482(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_sebastian(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_simonetta(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_sixtus-ii-1481(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_st-augustine(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_st-augustine-in-his-cell-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_st-augustine-in-his-study-predella-panel-from-the-altarpiece-of-st-mark-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_st-dominic(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_st-jerome(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_st-jerome-in-penitence-predella-panel-from-the-altarpiece-of-st-mark-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_st-john-on-patmos-1492(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_study-of-two-standing-figures(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-abyss-of-hell-1480(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-agony-in-the-garden(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-annunciation-1500(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-annunciation-predella-panel-from-the-altarpiece-of-st-mark-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-birth-of-venus-1485(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-cestello-annunciation(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-coronation-of-the-virgin-altarpiece-of-st-mark(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-discovery-of-the-body-of-holofernes(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-extraction-of-the-heart-of-st-ignatius-from-the-altarpiece-of-st-barnabas-1488(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-flagellation(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-flight-into-egypt(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-madonna-and-child-with-the-infant-saint-john-the-baptist(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-madonna-of-the-roses(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-miracle-of-st-eligius-predella-panel-from-the-altarpiece-of-st-mark-1492(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-mystical-nativity(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-outcast(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-punishment-of-korah-dathan-and-abiram-1481(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-resurrection(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-return-of-judith-to-bethulia-1473(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-story-of-lucretia-1504(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-story-of-nastagio(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-story-of-nastagio-degli-onesti-1483(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-story-of-nastagio-degli-onesti-i-from-the-decameron-by-boccaccio-1483(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-story-of-nastagio-degli-onesti-the-banquet-in-the-pine-forest-1483(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-story-of-virginia-1504(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-temptation-of-christ-1482(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-triumph-of-mordecai-from-the-story-of-esther-1480(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-virgin-adoring-the-child(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-virgin-adoring-the-child-1(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-virgin-adoring-the-child-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-virgin-and-child-enthroned-1484(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-virgin-and-child-surrounded-by-five-angels(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-virgin-and-child-with-the-infant-st-john(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-virgin-and-child-with-two-angels-and-st-john-the-baptist(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-vision-of-st-augustine-from-the-altarpiece-of-st-barnabas(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-youth-moses-1482(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_the-youth-moses-detail-1482(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_three-angels-1480(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_three-miracles-of-st-zenobius-1505(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_three-miracles-of-st-zenobius-1505-1(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_three-scenes-from-the-story-of-esther(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_transfiguration-st-jerome-st-augustine-1500(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_trinity(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_venus-and-mars(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_venus-and-the-graces-offering-gifts-to-a-young-girl-1486(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_virgin-and-child-with-saints-from-the-altarpiece-of-san-barnabas-1488(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_virgin-and-child-with-the-infant-st-john-the-baptistbetween-1500(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_virgin-and-child-with-two-angels-1469(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_woman-with-attributes-of-saint-catherine-so-called-catherina-sforza-sandro-botticelli-1475(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_workshop-of-esther-at-the-palace-gate-1480(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sandro-botticelli_young-man-greeted-by-seven-liberal-arts-1490(1).jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_a-portrait-of-a-young-alessandro-farnese-the-future-duke-of-parma.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_bernardino-campi-painting-sofonisba-anguissola-1559.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_family-portrait-minerva-amilcare-and-asdrubale-anguissola-1557.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_infantas-isabella-clara-eugenia-and-catalina-micaela-1570.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_infantin-isabella-clara-eugenia-1573.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_lucia-minerva-and-europa-anguissola-playing-chess-1555.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-a-boy-at-the-spanish-court-1570.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-a-young-woman-in-profile.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-bianca-ponzoni-anguissola-the-artist-s-mother-1557.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-caterina-micaela-of-spain-1578.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-diane-d-andouins-and-her-daughter-1565.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-elena-anguissola-1551.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-giuliano-ii-cesarini-aged-14-1586.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-juana-of-austria-with-a-young-girl-1561.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-massimiliano-stampa-1557.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-minerva-anguissola.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-philipp-ii-of-spain-1570.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_portrait-of-queen-elisabeth-of-spain-1599.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_self-portrait-1554.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_self-portrait-1610.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_self-portrait-at-the-easel-1556.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/sofonisba-anguissola_three-children-with-dog-1590.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-faith.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-generosity.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-goodness.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-happiness.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-prudence.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-the-scuola-della-misericordia.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-the-scuola-di-san-giovanni-evangelista.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-the-scuola-di-san-marco.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-the-scuola-di-san-teodoro.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_allegory-of-truth.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_angelica-and-the-hermit.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_annunciation-1581.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_annunciation-maria-1594.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_annunciation-the-angel-1594.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_a-philosopher-1570.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_apollo-possibly-hymen-crowning-a-poet-and-giving-him-a-spouse.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_aretino-in-the-studio-of-tintoretto.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_ascension-of-christ-1581.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_assumption-of-the-virgin.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_autumn.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_bacchus-and-ariadne-1578.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_baptism-of-christ.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_battle-between-turks-and-christians-1589.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_battle-of-asola.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_battle-of-the-archangel-michael-and-the-satan.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_birth-of-st-john-the-baptist.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_camerlenghi-madonna-madonna-of-the-treasurers.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-and-the-adulteress-1594.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-and-the-woman-taken-in-adultery.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-before-pilate-1567.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-carried-to-the-tomb.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-in-the-house-of-the-pharisee.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-on-the-sea-of-galilee-1580.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-washing-the-feet-of-his-disciples.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-washing-the-feet-of-the-disciples.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_christ-with-mary-and-martha.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_conquest-of-zara-1584.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_creation-of-the-animals-1551.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_crucifixion.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_crucifixion-1565.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_crucifixion-1565-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_danae-1578.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_defence-of-brescia-1584.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_deploration-of-christ-1559.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_deposition.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_deucalion-and-pyrrha-praying-before-the-statue-of-the-goddess-themis.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_doge-alvise-i-mocenigo-and-family-before-the-madonna.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_doge-alvise-mocenigo.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_doge-gerolamo-priuli-tintoretto.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_do-not-touch-me.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_double-portrait-of-two-men.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_ecce-homo-1567.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_ecce-homo-pontius-pilate-presenting-christ-to-the-crowd-1547.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_elijah-fed-by-the-angel-1578.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_elisha-multiplies-the-bread-1578.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_entombment-1594.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_esther-before-ahasuerus-1548.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_federico-i-gonzaga-the-city-of-legnano-1580.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_finding-of-moses.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_finding-of-the-body-of-st-mark.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_finding-the-true-cross-1578.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_francesco-ii-gonzaga-against-charles-viii-of-france-1495-in-fighting-the-battle-of-the-taro-1580.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_frederick-ii-conquered-parma-in-1521-1579.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_galeas-for-montes.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_jacob-s-ladder-1578.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_jacopo-robusti-il-tintoretto-flora.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_jonah-leaves-the-whale-s-belly-1578.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_joseph-and-potiphar-s-wife.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_judith-and-holofernes.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_lamentation.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_lamentation-over-the-dead-christ.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_last-supper.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_madonna-with-child-and-donor-tintoretto.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_man-in-armour.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_man-with-gold-chain.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_marcantonio-barbaro.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_marriage-at-cana-1561.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_mercury-and-the-graces-1577.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_minerva-sending-away-mars-from-peace-and-prosperity-1577.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_miracle-of-the-manna.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_moses-drawing-water-from-the-rock-1577.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_moses-receiving-the-tables-of-the-law-1562.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_muse-with-lute-1594.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_paradies.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_paradise.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-collector-1565.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-distinguished-man.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-doge.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-genoese-nobleman.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-agostino-doria-1553.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-alvise-cornaro-1565.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-man.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-man-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-man-1550.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-man-2.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-man-3.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-man-aged-twenty-six-1547.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-procurator-of-st-mark-s.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-senator.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-senator-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-venetian-admiral.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-venetian-senator.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-venetian-senator-1580.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-white-bearded-man.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-woman.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-woman-revealing-her-breasts.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-young-gentleman.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-a-young-man.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-doge-girolamo-priuli-1559.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-doge-pietro-loredan-1570.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-doge-pietro-loredano.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/test/tintoretto_portrait-of-giovanni-paolo-cornaro-1561.jpg
# ...
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pietro-perugino_vallombrosa-altar-detail.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pietro-perugino_virgin-and-child-between-sts-john-the-baptist-and-catherine.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pietro-perugino_virgin-and-st-jerome-and-st-augustine.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pietro-perugino_virgin-enthroned-with-saints-catherine-of-alexandria-and-biagio.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pietro-perugino_virgin-with-a-child-st-john-and-an-angel-madonna-del-sacco.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_ceiling-decoration-detail-1503.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_ceiling-of-the-piccolomini-library-in-siena-cathedral-1507.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_christ-among-the-doctors-1501.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_madonna-with-writing-child-1498.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_madonna-with-writing-child-and-bishop-1495.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_madonna-with-writing-child-and-st-jerome-1481.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_painting-cycle-for-the-miracles-of-st-bernard-scene-healing-the-blind-and-deaf-riccardo-micuzio-1473.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_portrait-of-a-boy-1500.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_portrait-of-a-young-man-1502.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_portrait-of-the-donor-1504.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_riconciliazione-di-coriolano-1509.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_saint-bernardino-releases-a-prisoner-1473.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_saint-jerome-in-the-wilderness-1480.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_self-portrait-in-the-baglioni-chapel-1501.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_semi-gods-ceiling-1490.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_st-catherine-s-disputation-detail-1491.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_st-catherine-s-disputation-detail-1494.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_the-adoration-of-the-shepherds-1501.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_the-annunciation-1501.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_the-arithmetic-1491.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_the-crucifixion-with-sts-jerome-and-christopher-1471.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_the-glory-of-st-bernardino-1486.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pinturicchio_the-resurrection.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_apes-1430.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_apparition-of-the-virgin-to-sts-anthony-abbot-and-george.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_dog.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_duck-1440.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_hanged-men-and-two-portraits-1430.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_horses-1433.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_portrait-of-emperor-sigismund-of-luxembourg-1433.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_stork-1430.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_study-of-a-head-1436.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_study-of-a-young-man-with-his-hands-tied-behind-his-back-1438.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_study-of-horse-heads-1433.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_study-of-the-head-of-a-horse-1439.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_the-vision-of-saint-eustace-1438.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/pisanello_three-cows-1440.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_adam-and-eve-from-the-stanza-della-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_adam-and-eve-from-the-stanza-della-segnatura-detail-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_angel-fragment-of-the-baronci-altarpiece.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_angel-from-the-polyptych-of-st-nicolas-of-tolentino-1501.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_apollo-and-marsyas-from-the-stanza-della-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_birth-on-good-friday.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_bridgewater-madonna-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_ceiling-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_ceiling-of-the-loggia-of-psyche-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_christ-blessing-1502.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_christ-s-charge-to-st-peter-cartoon-for-the-sistine-chapel.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_colonna-madonna.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_crucifixion-1503.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_cupid-and-the-three-graces-1517.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_detail-of-the-tempi-madonna-1508.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_diotalevi-madonna-1503.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_disputation-of-the-holy-sacrament-detail-1510.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_expulsion-of-heliodorus-from-the-temple-detail.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_galatea-detail-of-mermen-and-dolphins-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_galatea-detail-of-putto-and-dolphins-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_gregory-ix-approving-the-decretals-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_hanno-the-pope-s-leo-x-elephant-1516.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_head-of-a-woman-1520.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_holy-family-known-as-the-grande-famille-of-francois-i-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_isaac-and-rebecca-spied-upon-by-abimelech-1519.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_jacob-s-dream-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_jacob-s-encounter-with-rachel-1519.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_joanna-of-aragon-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_justice-from-the-stanza-della-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_kneeling-nude-woman.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_lamentation-over-the-dead-christ.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-and-child.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-and-child-1505.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-and-child-enthroned-with-saints-1505.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-della-tenda.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-in-the-meadow-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-of-the-baldacchino.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-of-the-cloth.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-of-the-cloth-detail.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-of-the-goldfinch.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-studies-1513.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-with-child-and-saints.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-with-child-and-st-john-the-baptist.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_madonna-with-the-baldachino-detail-1508.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_miraculous-draught-of-fishes.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_miraculous-draught-of-fishes-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_moses-receiving-the-tablets-of-the-law-detail-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_moses-saved-from-the-water-1519.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_niccolini-cowper-madonna-1508.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_nude-study.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_philosophy-from-the-stanza-della-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_poetry-from-the-stanza-della-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_pope-leo-i-repulsing-attila-1514.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-a-cardinal.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-agnolo-doni-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-a-lady-with-a-unicorn-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-a-man.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-a-man-holding-an-apple-1500.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-andrea-navagero-and-agostino-beazzano.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-a-woman-la-muta-1507.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-a-young-man-1515.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-a-young-woman.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-a-young-woman-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-baldassare-castiglione-1516.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-bindo-altoviti-1515.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-cardinal-dovizzi-de-bibbiena.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-elizabeth-gonzaga.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-guidobaldo-da-montefeltro-duke-of-urbino.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-maddalena-doni-1506.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-pope-julius-ii.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portrait-of-the-young-pietro-bembo-1504.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_portraits-of-leo-x-cardinal-luigi-de-rossi-and-giulio-de-medici-1518.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_prime-mover-from-the-stanza-della-segnatura-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_psyche-presenting-venus-with-water-from-the-styx-1517.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_psyche-received-on-olympus-detail-1517.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_putti-detail-from-the-sistine-madonna-1513.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_saint-john-the-baptist-preaching-1505.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_scenes-from-the-life-of-david-1519.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_school-of-athens-detail-from-right-hand-side-showing-diogenes-on-the-steps-and-euclid-1511.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_self-portrait.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_self-portrait-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_self-portrait-with-a-friend.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_solly-madonna.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_st-catherine-of-alexandria-1508.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_st-cecilia-with-saints-detail-1516.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_st-cecilia-with-saints-detail-1516-1.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_st-cecilia-with-sts-paul-john-evangelists-augustine-and-mary-magdalene-1516.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_st-george-and-the-dragon.jpg
#   inflating: /content/drive/MyDrive/deeplearning/resource/painting/val/raphael_st-george-and-the-dragon-1506.jpg

# %%
import tensorflow as tf
import numpy as np
from scipy.misc import imsave
import os
import shutil
from PIL import Image
import time
import random
import sys

# %% [markdown]
# #Parameters

# %% [markdown]
# These are the parameters, that are essential throughout the whole CycleGAN. We define them here once, in one place, because these are used in multiple locations in the code.

# %%
img_height = 256
img_width = 256
img_layer = 3
img_size = img_height * img_width
output_path = "/content/drive/MyDrive/deeplearning/gan_output"
check_dir = "/content/drive/MyDrive/deeplearning/gan_output/checkpoints/"
temp_check = 0
max_epoch = 1
max_images = 100
h1_size = 150
h2_size = 300
z_size = 100
batch_size = 1
pool_size = 50
sample_size = 10
ngf = 32
ndf = 64

# %% [markdown]
# # Layers

# %% [markdown]
# We use convolutional layers, as building blocks for our Generators and Dsicriminators. The activation functions, that are used inside the nets are ReLU and LeakyReLU. These are just initial implementations, in the near future they will be a little bit tweaked, to improve the first results.

# %%
def lrelu(x, leak=0.2, name="lrelu", alt_relu_impl=False):

    with tf.variable_scope(name):
        if alt_relu_impl:
            f1 = 0.5 * (1 + leak)
            f2 = 0.5 * (1 - leak)
            # lrelu = 1/2 * (1 + leak) * x + 1/2 * (1 - leak) * |x|
            return f1 * x + f2 * abs(x)
        else:
            return tf.maximum(x, leak*x)

def instance_norm(x):

    with tf.variable_scope("instance_norm"):
        epsilon = 1e-5
        mean, var = tf.nn.moments(x, [1, 2], keep_dims=True)
        scale = tf.get_variable('scale',[x.get_shape()[-1]], 
            initializer=tf.truncated_normal_initializer(mean=1.0, stddev=0.02))
        offset = tf.get_variable('offset',[x.get_shape()[-1]],initializer=tf.constant_initializer(0.0))
        out = scale*tf.div(x-mean, tf.sqrt(var+epsilon)) + offset

        return out


def general_conv2d(inputconv, o_d=64, f_h=7, f_w=7, s_h=1, s_w=1, stddev=0.02, padding="VALID", name="conv2d", do_norm=True, do_relu=True, relufactor=0):
    with tf.variable_scope(name):
        
        conv = tf.contrib.layers.conv2d(inputconv, o_d, f_w, s_w, padding, activation_fn=None, weights_initializer=tf.truncated_normal_initializer(stddev=stddev),biases_initializer=tf.constant_initializer(0.0))
        if do_norm:
            conv = instance_norm(conv)
            # conv = tf.contrib.layers.batch_norm(conv, decay=0.9, updates_collections=None, epsilon=1e-5, scale=True, scope="batch_norm")
            
        if do_relu:
            if(relufactor == 0):
                conv = tf.nn.relu(conv,"relu")
            else:
                conv = lrelu(conv, relufactor, "lrelu")

        return conv



def general_deconv2d(inputconv, outshape, o_d=64, f_h=7, f_w=7, s_h=1, s_w=1, stddev=0.02, padding="VALID", name="deconv2d", do_norm=True, do_relu=True, relufactor=0):
    with tf.variable_scope(name):

        conv = tf.contrib.layers.conv2d_transpose(inputconv, o_d, [f_h, f_w], [s_h, s_w], padding, activation_fn=None, weights_initializer=tf.truncated_normal_initializer(stddev=stddev),biases_initializer=tf.constant_initializer(0.0))
        
        if do_norm:
            conv = instance_norm(conv)
            # conv = tf.contrib.layers.batch_norm(conv, decay=0.9, updates_collections=None, epsilon=1e-5, scale=True, scope="batch_norm")
            
        if do_relu:
            if(relufactor == 0):
                conv = tf.nn.relu(conv,"relu")
            else:
                conv = lrelu(conv, relufactor, "lrelu")

        return conv

# %% [markdown]
# #Generator, Discriminator

# %% [markdown]
# Here first we can see ResNET block definitions. We use these, because it is proved, that in convolutional nets these are said to be default. We use these in our generators (with a last activation tanh), the discriminators are simple convolutional networks.

# %%
def build_resnet_block(inputres, dim, name="resnet"):
    
    with tf.variable_scope(name):

        out_res = tf.pad(inputres, [[0, 0], [1, 1], [1, 1], [0, 0]], "REFLECT")
        out_res = general_conv2d(out_res, dim, 3, 3, 1, 1, 0.02, "VALID","c1")
        out_res = tf.pad(out_res, [[0, 0], [1, 1], [1, 1], [0, 0]], "REFLECT")
        out_res = general_conv2d(out_res, dim, 3, 3, 1, 1, 0.02, "VALID","c2",do_relu=False)
        
        return tf.nn.relu(out_res + inputres)


# def build_generator_resnet_6blocks(inputgen, name="generator"):
#     with tf.variable_scope(name):
#         f = 7
#         ks = 3
        
#         pad_input = tf.pad(inputgen,[[0, 0], [ks, ks], [ks, ks], [0, 0]], "REFLECT")
#         o_c1 = general_conv2d(pad_input, ngf, f, f, 1, 1, 0.02,name="c1")
#         o_c2 = general_conv2d(o_c1, ngf*2, ks, ks, 2, 2, 0.02,"SAME","c2")
#         o_c3 = general_conv2d(o_c2, ngf*4, ks, ks, 2, 2, 0.02,"SAME","c3")

#         o_r1 = build_resnet_block(o_c3, ngf*4, "r1")
#         o_r2 = build_resnet_block(o_r1, ngf*4, "r2")
#         o_r3 = build_resnet_block(o_r2, ngf*4, "r3")
#         o_r4 = build_resnet_block(o_r3, ngf*4, "r4")
#         o_r5 = build_resnet_block(o_r4, ngf*4, "r5")
#         o_r6 = build_resnet_block(o_r5, ngf*4, "r6")

#         o_c4 = general_deconv2d(o_r6, [batch_size,64,64,ngf*2], ngf*2, ks, ks, 2, 2, 0.02,"SAME","c4")
#         o_c5 = general_deconv2d(o_c4, [batch_size,128,128,ngf], ngf, ks, ks, 2, 2, 0.02,"SAME","c5")
#         o_c5_pad = tf.pad(o_c5,[[0, 0], [ks, ks], [ks, ks], [0, 0]], "REFLECT")
#         o_c6 = general_conv2d(o_c5_pad, img_layer, f, f, 1, 1, 0.02,"VALID","c6",do_relu=False)

#         # Adding the tanh layer

#         out_gen = tf.nn.tanh(o_c6,"t1")


#         return out_gen

def build_generator_resnet_9blocks(inputgen, name="generator"):
    with tf.variable_scope(name):
        f = 7
        ks = 3
        
        pad_input = tf.pad(inputgen,[[0, 0], [ks, ks], [ks, ks], [0, 0]], "REFLECT")
        o_c1 = general_conv2d(pad_input, ngf, f, f, 1, 1, 0.02,name="c1")
        o_c2 = general_conv2d(o_c1, ngf*2, ks, ks, 2, 2, 0.02,"SAME","c2")
        o_c3 = general_conv2d(o_c2, ngf*4, ks, ks, 2, 2, 0.02,"SAME","c3")

        o_r1 = build_resnet_block(o_c3, ngf*4, "r1")
        o_r2 = build_resnet_block(o_r1, ngf*4, "r2")
        o_r3 = build_resnet_block(o_r2, ngf*4, "r3")
        o_r4 = build_resnet_block(o_r3, ngf*4, "r4")
        o_r5 = build_resnet_block(o_r4, ngf*4, "r5")
        o_r6 = build_resnet_block(o_r5, ngf*4, "r6")
        o_r7 = build_resnet_block(o_r6, ngf*4, "r7")
        o_r8 = build_resnet_block(o_r7, ngf*4, "r8")
        o_r9 = build_resnet_block(o_r8, ngf*4, "r9")

        o_c4 = general_deconv2d(o_r9, [batch_size,128,128,ngf*2], ngf*2, ks, ks, 2, 2, 0.02,"SAME","c4")
        o_c5 = general_deconv2d(o_c4, [batch_size,256,256,ngf], ngf, ks, ks, 2, 2, 0.02,"SAME","c5")
        o_c6 = general_conv2d(o_c5, img_layer, f, f, 1, 1, 0.02,"SAME","c6",do_relu=False)

        # Adding the tanh layer

        out_gen = tf.nn.tanh(o_c6,"t1")


        return out_gen


def build_gen_discriminator(inputdisc, name="discriminator"):

    with tf.variable_scope(name):
        f = 4

        o_c1 = general_conv2d(inputdisc, ndf, f, f, 2, 2, 0.02, "SAME", "c1", do_norm=False, relufactor=0.2)
        o_c2 = general_conv2d(o_c1, ndf*2, f, f, 2, 2, 0.02, "SAME", "c2", relufactor=0.2)
        o_c3 = general_conv2d(o_c2, ndf*4, f, f, 2, 2, 0.02, "SAME", "c3", relufactor=0.2)
        o_c4 = general_conv2d(o_c3, ndf*8, f, f, 1, 1, 0.02, "SAME", "c4",relufactor=0.2)
        o_c5 = general_conv2d(o_c4, 1, f, f, 1, 1, 0.02, "SAME", "c5",do_norm=False,do_relu=False)

        return o_c5


# def patch_discriminator(inputdisc, name="discriminator"):

#     with tf.variable_scope(name):
#         f= 4

#         patch_input = tf.random_crop(inputdisc,[1,70,70,3])
#         o_c1 = general_conv2d(patch_input, ndf, f, f, 2, 2, 0.02, "SAME", "c1", do_norm="False", relufactor=0.2)
#         o_c2 = general_conv2d(o_c1, ndf*2, f, f, 2, 2, 0.02, "SAME", "c2", relufactor=0.2)
#         o_c3 = general_conv2d(o_c2, ndf*4, f, f, 2, 2, 0.02, "SAME", "c3", relufactor=0.2)
#         o_c4 = general_conv2d(o_c3, ndf*8, f, f, 2, 2, 0.02, "SAME", "c4", relufactor=0.2)
#         o_c5 = general_conv2d(o_c4, 1, f, f, 1, 1, 0.02, "SAME", "c5",do_norm=False,do_relu=False)

#         return o_c5

# %% [markdown]
# #CycleGAN

# %% [markdown]
# Here is the final model in the making. It contains the image preparation for this network (.jpg images are expected). There are two imput setup: one for training, and one for testing. The training process will be done by the face_detections train images and the renessaince train images, the testing is done by the output of the face detection network's algorithm, and the testing paintings. If interested in CycleGAN, here is the original paper : https://arxiv.org/pdf/1703.10593.pdf

# %%
save_training_images = True

class CycleGAN():

    def input_setup(self):

        ''' 
        This function basically setup variables for taking image input.
        filenames_A/filenames_B -> takes the list of all training images
        self.image_A/self.image_B -> Input image with each values ranging from [-1,1]
        '''

        def decode_img(file_path):
          file = tf.io.read_file(file_path)
          img = tf.image.decode_jpeg(file, channels=3)
          img = tf.subtract(tf.divide(tf.image.resize(img, [256, 256]),127.5),1)
          return img  

        img_path = "/content/drive/MyDrive/deeplearning/resource/input/"
        image_file_A = tf.data.Dataset.list_files(str(img_path + '*.jpg'))

        self.image_A = image_file_A.map(decode_img)

        img_path = "/content/drive/MyDrive/deeplearning/resource/painting/train/"
        image_file_B = tf.data.Dataset.list_files(str(img_path + '*.jpg'))

        seimages_B = image_file_B.map(decode_img)


        # filenames_A = tf.io.match_filenames_once("/content/drive/MyDrive/deeplearning/resource/input/face_detection/test/*.jpg")    
        # self.queue_length_A = tf.size(filenames_A)
        # filenames_B = tf.io.match_filenames_once("/content/drive/MyDrive/deeplearning/resource/painting/train/*.jpg")    
        # self.queue_length_B = tf.size(filenames_B)
        
        # filename_queue_A = tf.data.Dataset.from_tensor_slices(filenames_A)
        # filename_queue_B = tf.data.Dataset.from_tensor_slices(filenames_B)
        # print(filenames_A)


        # image_reader = tf.compat.v1.WholeFileReader()
        # _, image_file_A = filename_queue_A.map(tf.io.read_file)
        # _, image_file_B = image_reader.read(filename_queue_B)

        self.image_A = tf.subtract(tf.divide(tf.image.resize(images_A, [256, 256]),127.5),1)
        self.image_B = tf.subtract(tf.divide(tf.image.resize(images_B, [256, 256]),127.5),1)

    def input_setup_test(self):

        ''' 
        This function basically setup variables for taking image input for test.
        filenames_A/filenames_B -> takes the list of all training images
        self.image_A/self.image_B -> Input image with each values ranging from [-1,1]
        '''

        filenames_A = tf.io.match_filenames_once("/content/drive/MyDrive/deeplearning/resource/gan_input_images/*.jpg")    
        self.queue_length_A = tf.size(filenames_A)
        filenames_B = tf.io.match_filenames_once("/content/drive/MyDrive/deeplearning/resource/painting/test/*.jpg")
        self.queue_length_B = tf.size(filenames_B)
        
        filename_queue_A = tf.train.string_input_producer(filenames_A)
        filename_queue_B = tf.train.string_input_producer(filenames_B)

        image_reader = tf.WholeFileReader()
        _, image_file_A = image_reader.read(filename_queue_A)
        _, image_file_B = image_reader.read(filename_queue_B)

        self.image_A = tf.subtract(tf.div(tf.image.resize_images(tf.image.decode_jpeg(image_file_A),[256,256]),127.5),1)
        self.image_B = tf.subtract(tf.div(tf.image.resize_images(tf.image.decode_jpeg(image_file_B),[256,256]),127.5),1)

    

    def input_read(self, sess):


        '''
        It reads the input into from the image folder.
        self.fake_images_A/self.fake_images_B -> List of generated images used for calculation of loss function of Discriminator
        self.A_input/self.B_input -> Stores all the training images in python list
        '''

        # Loading images into the tensors
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(coord=coord)

        num_files_A = sess.run(self.queue_length_A)
        num_files_B = sess.run(self.queue_length_B)

        self.fake_images_A = np.zeros((pool_size,1,img_height, img_width, img_layer))
        self.fake_images_B = np.zeros((pool_size,1,img_height, img_width, img_layer))


        self.A_input = np.zeros((max_images, batch_size, img_height, img_width, img_layer))
        self.B_input = np.zeros((max_images, batch_size, img_height, img_width, img_layer))

        for i in range(max_images): 
            image_tensor = sess.run(self.image_A)
            if(image_tensor.size() == img_size*batch_size*img_layer):
                self.A_input[i] = image_tensor.reshape((batch_size,img_height, img_width, img_layer))

        for i in range(max_images):
            image_tensor = sess.run(self.image_B)
            if(image_tensor.size() == img_size*batch_size*img_layer):
                self.B_input[i] = image_tensor.reshape((batch_size,img_height, img_width, img_layer))


        coord.request_stop()
        coord.join(threads)




    def model_setup(self):

        ''' This function sets up the model to train
        self.input_A/self.input_B -> Set of training images.
        self.fake_A/self.fake_B -> Generated images by corresponding generator of input_A and input_B
        self.lr -> Learning rate variable
        self.cyc_A/ self.cyc_B -> Images generated after feeding self.fake_A/self.fake_B to corresponding generator. This is use to calcualte cyclic loss
        '''

        self.input_A = tf.placeholder(tf.float32, [batch_size, img_width, img_height, img_layer], name="input_A")
        self.input_B = tf.placeholder(tf.float32, [batch_size, img_width, img_height, img_layer], name="input_B")
        
        self.fake_pool_A = tf.placeholder(tf.float32, [None, img_width, img_height, img_layer], name="fake_pool_A")
        self.fake_pool_B = tf.placeholder(tf.float32, [None, img_width, img_height, img_layer], name="fake_pool_B")

        self.global_step = tf.Variable(0, name="global_step", trainable=False)

        self.num_fake_inputs = 0

        self.lr = tf.placeholder(tf.float32, shape=[], name="lr")

        with tf.variable_scope("Model") as scope:
            self.fake_B = build_generator_resnet_9blocks(self.input_A, name="g_A")
            self.fake_A = build_generator_resnet_9blocks(self.input_B, name="g_B")
            self.rec_A = build_gen_discriminator(self.input_A, "d_A")
            self.rec_B = build_gen_discriminator(self.input_B, "d_B")

            scope.reuse_variables()

            self.fake_rec_A = build_gen_discriminator(self.fake_A, "d_A")
            self.fake_rec_B = build_gen_discriminator(self.fake_B, "d_B")
            self.cyc_A = build_generator_resnet_9blocks(self.fake_B, "g_B")
            self.cyc_B = build_generator_resnet_9blocks(self.fake_A, "g_A")

            scope.reuse_variables()

            self.fake_pool_rec_A = build_gen_discriminator(self.fake_pool_A, "d_A")
            self.fake_pool_rec_B = build_gen_discriminator(self.fake_pool_B, "d_B")

    def loss_calc(self):

        ''' In this function we are defining the variables for loss calcultions and traning model
        d_loss_A/d_loss_B -> loss for discriminator A/B
        g_loss_A/g_loss_B -> loss for generator A/B
        *_trainer -> Variaous trainer for above loss functions
        *_summ -> Summary variables for above loss functions'''

        cyc_loss = tf.reduce_mean(tf.abs(self.input_A-self.cyc_A)) + tf.reduce_mean(tf.abs(self.input_B-self.cyc_B))
        
        disc_loss_A = tf.reduce_mean(tf.squared_difference(self.fake_rec_A,1))
        disc_loss_B = tf.reduce_mean(tf.squared_difference(self.fake_rec_B,1))
        
        g_loss_A = cyc_loss*10 + disc_loss_B
        g_loss_B = cyc_loss*10 + disc_loss_A

        d_loss_A = (tf.reduce_mean(tf.square(self.fake_pool_rec_A)) + tf.reduce_mean(tf.squared_difference(self.rec_A,1)))/2.0
        d_loss_B = (tf.reduce_mean(tf.square(self.fake_pool_rec_B)) + tf.reduce_mean(tf.squared_difference(self.rec_B,1)))/2.0

        
        optimizer = tf.train.AdamOptimizer(self.lr, beta1=0.5)

        self.model_vars = tf.trainable_variables()

        d_A_vars = [var for var in self.model_vars if 'd_A' in var.name]
        g_A_vars = [var for var in self.model_vars if 'g_A' in var.name]
        d_B_vars = [var for var in self.model_vars if 'd_B' in var.name]
        g_B_vars = [var for var in self.model_vars if 'g_B' in var.name]
        
        self.d_A_trainer = optimizer.minimize(d_loss_A, var_list=d_A_vars)
        self.d_B_trainer = optimizer.minimize(d_loss_B, var_list=d_B_vars)
        self.g_A_trainer = optimizer.minimize(g_loss_A, var_list=g_A_vars)
        self.g_B_trainer = optimizer.minimize(g_loss_B, var_list=g_B_vars)

        for var in self.model_vars: print(var.name)

        #Summary variables for tensorboard

        self.g_A_loss_summ = tf.summary.scalar("g_A_loss", g_loss_A)
        self.g_B_loss_summ = tf.summary.scalar("g_B_loss", g_loss_B)
        self.d_A_loss_summ = tf.summary.scalar("d_A_loss", d_loss_A)
        self.d_B_loss_summ = tf.summary.scalar("d_B_loss", d_loss_B)

    def save_training_images(self, sess, epoch):

        if not os.path.exists("/content/drive/MyDrive/deeplearning/gan_output/imgs"):
            os.makedirs("/content/drive/MyDrive/deeplearning/gan_output/imgs")

        for i in range(0,10):
            fake_A_temp, fake_B_temp, cyc_A_temp, cyc_B_temp = sess.run([self.fake_A, self.fake_B, self.cyc_A, self.cyc_B],feed_dict={self.input_A:self.A_input[i], self.input_B:self.B_input[i]})
            imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/fakeA_"+ str(epoch) + "_" + str(i)+".jpg",((fake_A_temp[0]+1)*127.5).astype(np.uint8))
            imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/fakeB_"+ str(epoch) + "_" + str(i)+".jpg",((fake_B_temp[0]+1)*127.5).astype(np.uint8))
            imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/cycA_"+ str(epoch) + "_" + str(i)+".jpg",((cyc_A_temp[0]+1)*127.5).astype(np.uint8))
            imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/cycB_"+ str(epoch) + "_" + str(i)+".jpg",((cyc_B_temp[0]+1)*127.5).astype(np.uint8))
            imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/inputA_"+ str(epoch) + "_" + str(i)+".jpg",((self.A_input[i][0]+1)*127.5).astype(np.uint8))
            imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/inputB_"+ str(epoch) + "_" + str(i)+".jpg",((self.B_input[i][0]+1)*127.5).astype(np.uint8))

    def fake_image_pool(self, num_fakes, fake, fake_pool):
        ''' This function saves the generated image to corresponding pool of images.
        In starting. It keeps on feeling the pool till it is full and then randomly selects an
        already stored image and replace it with new one.'''

        if(num_fakes < pool_size):
            fake_pool[num_fakes] = fake
            return fake
        else :
            p = random.random()
            if p > 0.5:
                random_id = random.randint(0,pool_size-1)
                temp = fake_pool[random_id]
                fake_pool[random_id] = fake
                return temp
            else :
                return fake


    def train(self):


        ''' Training Function '''


        # Load Dataset from the dataset folder
        self.input_setup()  

        #Build the network
        self.model_setup()

        #Loss function calculations
        self.loss_calc()
      
        # Initializing the global variables
        init = tf.global_variables_initializer()
        saver = tf.train.Saver()     

        with tf.Session() as sess:
            sess.run(init)

            #Read input to nd array
            self.input_read(sess)

            #Restore the model to run the model from last checkpoint
            if to_restore:
                chkpt_fname = tf.train.latest_checkpoint(check_dir)
                saver.restore(sess, chkpt_fname)

            writer = tf.summary.FileWriter("/content/drive/MyDrive/deeplearning/gan_output/2")

            if not os.path.exists(check_dir):
                os.makedirs(check_dir)

            # Training Loop
            for epoch in range(sess.run(self.global_step),100):                
                print ("In the epoch ", epoch)
                saver.save(sess,os.path.join(check_dir,"cyclegan"),global_step=epoch)

                # Dealing with the learning rate as per the epoch number
                if(epoch < 100) :
                    curr_lr = 0.0002
                else:
                    curr_lr = 0.0002 - 0.0002*(epoch-100)/100

                if(save_training_images):
                    self.save_training_images(sess, epoch)

                # sys.exit()

                for ptr in range(0,max_images):
                    print("In the iteration ",ptr)
                    print("Starting",time.time()*1000.0)

                    # Optimizing the G_A network

                    _, fake_B_temp, summary_str = sess.run([self.g_A_trainer, self.fake_B, self.g_A_loss_summ],feed_dict={self.input_A:self.A_input[ptr], self.input_B:self.B_input[ptr], self.lr:curr_lr})
                    
                    writer.add_summary(summary_str, epoch*max_images + ptr)                    
                    fake_B_temp1 = self.fake_image_pool(self.num_fake_inputs, fake_B_temp, self.fake_images_B)
                    
                    # Optimizing the D_B network
                    _, summary_str = sess.run([self.d_B_trainer, self.d_B_loss_summ],feed_dict={self.input_A:self.A_input[ptr], self.input_B:self.B_input[ptr], self.lr:curr_lr, self.fake_pool_B:fake_B_temp1})
                    writer.add_summary(summary_str, epoch*max_images + ptr)
                    
                    
                    # Optimizing the G_B network
                    _, fake_A_temp, summary_str = sess.run([self.g_B_trainer, self.fake_A, self.g_B_loss_summ],feed_dict={self.input_A:self.A_input[ptr], self.input_B:self.B_input[ptr], self.lr:curr_lr})

                    writer.add_summary(summary_str, epoch*max_images + ptr)
                    
                    
                    fake_A_temp1 = self.fake_image_pool(self.num_fake_inputs, fake_A_temp, self.fake_images_A)

                    # Optimizing the D_A network
                    _, summary_str = sess.run([self.d_A_trainer, self.d_A_loss_summ],feed_dict={self.input_A:self.A_input[ptr], self.input_B:self.B_input[ptr], self.lr:curr_lr, self.fake_pool_A:fake_A_temp1})

                    writer.add_summary(summary_str, epoch*max_images + ptr)
                    
                    self.num_fake_inputs+=1
            
                        

                sess.run(tf.assign(self.global_step, epoch + 1))

            writer.add_graph(sess.graph)

    def test(self):


        ''' Testing Function'''

        print("Testing the results")

        self.input_setup_test()

        self.model_setup()
        saver = tf.train.Saver()
        init = tf.global_variables_initializer()

        with tf.Session() as sess:

            sess.run(init)

            self.input_read(sess)

            chkpt_fname = tf.train.latest_checkpoint(check_dir)
            saver.restore(sess, chkpt_fname)

            if not os.path.exists("/content/drive/MyDrive/deeplearning/gan_output/imgs/test/"):
                os.makedirs("/content/drive/MyDrive/deeplearning/gan_output/imgs/test/")            

            for i in range(0,100):
                fake_A_temp, fake_B_temp = sess.run([self.fake_A, self.fake_B],feed_dict={self.input_A:self.A_input[i], self.input_B:self.B_input[i]})
                imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/test/fakeA_"+str(i)+".jpg",((fake_A_temp[0]+1)*127.5).astype(np.uint8))
                imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/test/fakeB_"+str(i)+".jpg",((fake_B_temp[0]+1)*127.5).astype(np.uint8))
                imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/test/inputA_"+str(i)+".jpg",((self.A_input[i][0]+1)*127.5).astype(np.uint8))
                imsave("/content/drive/MyDrive/deeplearning/gan_output/imgs/test/inputB_"+str(i)+".jpg",((self.B_input[i][0]+1)*127.5).astype(np.uint8))

# %% [markdown]
# # Training

# %%
model = CycleGAN()
model.train()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-86dd7523ecba> in <module>()
#       1 model = CycleGAN()
# ----> 2 model.train()
#
# <ipython-input-18-fce2e62a6250> in train(self)
#     232
#     233         # Load Dataset from the dataset folder
# --> 234         self.input_setup()
#     235
#     236         #Build the network
#
# <ipython-input-18-fce2e62a6250> in input_setup(self)
#      42         # _, image_file_B = image_reader.read(filename_queue_B)
#      43
# ---> 44         self.image_A = tf.subtract(tf.divide(tf.image.resize(images_A, [256, 256]),127.5),1)
#      45         self.image_B = tf.subtract(tf.divide(tf.image.resize(images_B, [256, 256]),127.5),1)
#      46
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/image_ops_impl.py in resize_images_v2(images, size, method, preserve_aspect_ratio, antialias, name)
#    1645       preserve_aspect_ratio=preserve_aspect_ratio,
#    1646       name=name,
# -> 1647       skip_resize_if_same=False)
#    1648
#    1649
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/image_ops_impl.py in _resize_images_common(images, resizer_fn, size, preserve_aspect_ratio, name, skip_resize_if_same)
#    1309   """Core functionality for v1 and v2 resize functions."""
#    1310   with ops.name_scope(name, 'resize', [images, size]):
# -> 1311     images = ops.convert_to_tensor(images, name='images')
#    1312     if images.get_shape().ndims is None:
#    1313       raise ValueError('\'images\' contains no shape.')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     337                                          as_ref=False):
#     338   _ = as_ref
# --> 339   return constant(v, dtype=dtype, name=name)
#     340
#     341
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Attempt to convert a value (<MapDataset shapes: (256, 256), types: tf.uint8>) with an unsupported type (<class 'tensorflow.python.data.ops.dataset_ops.MapDataset'>) to a Tensor.

# %% [markdown]
# # Testing

# %%
model.test()

# %% [markdown]
# #Evaluation

# %% [markdown]
# As of now, i will use the Frechet Inception Distance, to evaluate the results. For this we will use generated images (by the test), and test images from the paintings.

# %%
# %cd /content
# !git clone https://github.com/tsc2017/Frechet-Inception-Distance.git
# %cd /content/Frechet-Inception-Distance

# %%
import fid.*

def decode_img(file_path):
  file = tf.io.read_file(file_path)
  img = tf.image.decode_jpeg(file, channels=3)
  return img

img_path = "/content/drive/MyDrive/deeplearning/resource/painting/test/"
real_painting_files = tf.data.Dataset.list_files(str(img_path + '*.jpg'))

real_paintings = real_painting_files.map(decode_img)

img_path = "/content/drive/MyDrive/deeplearning/gan_output/imgs/test/fakeB_"
fake_painting_files = tf.data.Dataset.list_files(str(img_path + '*.jpg'))

fake_paintings = fake_painting_files.map(decode_img)

_fid = get_fid(real_paintings, fake_paintings)
print(f'Fid: {_fid:.5}')
